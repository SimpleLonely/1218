# %%
from src.test_trader import Trader
import pandas as pd

# %%
df = pd.read_csv('src/input1016.csv')
df2 = pd.read_csv('res/origin1016.csv')

# %%
test_bars = df[-180:]
test_xaus = df2[-180:]

# %%
xaus = test_xaus['xau']

# %%
dates = test_xaus['date']

# %%
me = Trader()

# %%
for i in range(10381,10380+len(xaus)):
    price = xaus[i]
    time = dates[i]
    pre_price = xaus[i-1]
    if price>pre_price:
        if price<pre_price*0.98: # 如果涨幅达2%，平空仓，不开空仓，如果涨了但是不足2%，开多仓，不用平空仓
            print(str(time)+' price went up too high, stop shorting!')
            if me.put_position > 0:
                me.buy_close(me.put_position,price,time)
                print("I'am running away, bye!")
            else:
                print('I have no short position, take it easy.')
        else:
            me.buy_open(5, price, time)
    else:
        if price>pre_price*1.02:# 如果跌幅达2%，平多仓，不开空仓，如果跌了但是不足2%，开空仓，不用平多仓
            print(str(time)+' price went up too low, stop longing!')
            if me.call_position>0:
                me.sell_close(me.call_position,price,time)
                print("I'am running away, bye!")
            else:
                print("I have no long position, take it easy")
        else:
            me.sell_open(5, price, time)
    me.settle(price, time)

# %%
me.records.to_csv('records_reverse_2.csv', index=False)
me2 = Trader()

# %%
for i in range(10381,10380+len(xaus)):
    price = xaus[i]
    time = dates[i]
    pre_price = xaus[i-1]
    if price>pre_price:
        if price>pre_price*1.02: # 如果涨幅达2%，平空仓，不开空仓，如果涨了但是不足2%，开多仓，不用平空仓
            print(str(time)+' price went up too high, stop shorting!')
            if me2.put_position > 0:
                me2.buy_close(me2.put_position,price,time)
                print("I'am running away, bye!")
            else:
                print('I have no short position, take it easy.')
        else:
            me2.buy_open(5, price, time)
    else:
        if price<pre_price*0.98:# 如果跌幅达2%，平多仓，不开空仓，如果跌了但是不足2%，开空仓，不用平多仓
            print(str(time)+' price went up too low, stop longing!')
            if me2.call_position>0:
                me2.sell_close(me2.call_position,price,time)
                print("I'am running away, bye!")
            else:
                print("I have no long position, take it easy")
        else:
            me2.sell_open(5, price, time)
    me2.settle(price, time)

# %%
me2.records

# %%
me2.records.to_csv('records_normal_2.csv', index=False)

# %% [markdown]
# # 从这开始真正的实验

# %%
import keras as k
from src.test_trader import Trader
import pandas as pd
import numpy as np

df = pd.read_csv('res/input1117.csv')
df['date'] = pd.to_datetime(df.date).apply(lambda x:x.timestamp()*1e3)
def ModelPredict(input):
    model = k.models.load_model('4NN.model')# 加载保存下来的模型
    return model.predict(input)# 直接用加载出来的模型，对输入 input 进行预测
# Out:
# Using TensorFlow backend.
# D:\Anaconda3\envs\inno\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# D:\Anaconda3\envs\inno\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# D:\Anaconda3\envs\inno\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# D:\Anaconda3\envs\inno\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# D:\Anaconda3\envs\inno\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# D:\Anaconda3\envs\inno\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# D:\Anaconda3\envs\inno\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# D:\Anaconda3\envs\inno\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# D:\Anaconda3\envs\inno\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# D:\Anaconda3\envs\inno\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# D:\Anaconda3\envs\inno\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# D:\Anaconda3\envs\inno\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
test_input = df.iloc[10000:, 2:-1].copy()

# %%
test_output = df.iloc[10000:, 0:2].copy()
test_output
xaus = list(test_output['xau'])
dates = list(test_output['date'])
xaus[1]
# Out:
# 1262.7

# %%
model = k.models.load_model('4NN.model')
# Out:
# WARNING:tensorflow:From D:\Anaconda3\envs\inno\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.

# %%
model.predict(test_input.iloc[1:2,:])[0][0]
# Out:
# 0.9705084

# %%
from highcharts import Highchart
from highcharts import Highstock
The_Graph = Highstock(width=1000, height=600)
The_Graph.add_data_set([(dates[x],xaus[x]) for x in range(0,len(xaus))], 'line', name='XAU', yAxis=0, color='black')
The_Graph.set_dict_options({
    'title' : {
        'text' : 'Strategy 1'
    },    
    'xAxis': {
        'type': 'datetime',
        'labels': {
            'step': 1, 
            'formatter': '''function () {
                return Highcharts.dateFormat('%Y-%m-%d', this.value);
            }'''
        }},

    'yAxis': [{ 
        'height': '100%',
        'lineWidth': 2,
    }],
    'legend': {
        'enabled': True
    },
})
The_Graph
# Out:
# <iframe style="border:0;outline:none;overflow:hidden" srcdoc="&lt;!DOCTYPE html&gt; &lt;html lang=&quot;en&quot;&gt; &lt;head&gt; &lt;meta charset=&quot;utf-8&quot; /&gt; &lt;link href=&quot;https://www.highcharts.com/highslide/highslide.css&quot; rel=&quot;stylesheet&quot; /&gt; &lt;script type=&quot;text/javascript&quot; src=&quot;https://ajax.googleapis.com/ajax/libs/jquery/1.9.1/jquery.min.js&quot;&gt;&lt;/script&gt; &lt;script type=&quot;text/javascript&quot; src=&quot;https://code.highcharts.com/stock/6/highstock.js&quot;&gt;&lt;/script&gt; &lt;script type=&quot;text/javascript&quot; src=&quot;https://code.highcharts.com/stock/6/modules/exporting.js&quot;&gt;&lt;/script&gt; &lt;script type=&quot;text/javascript&quot; src=&quot;https://code.highcharts.com/6/highcharts-more.js&quot;&gt;&lt;/script&gt; &lt;/head&gt; &lt;body style=&quot;margin:0;padding:0&quot;&gt; &lt;div id=&quot;container&quot; style=&quot;width:1000px;height:600px;&quot;&gt;Loading....&lt;/div&gt; &lt;script&gt; $(function(){ Highcharts.setOptions({&quot;global&quot;: {}, &quot;lang&quot;: {}}); var option = {&quot;chart&quot;: {&quot;renderTo&quot;: &quot;container&quot;, &quot;width&quot;: 1000, &quot;height&quot;: 600}, &quot;colors&quot;: {}, &quot;credits&quot;: {&quot;enabled&quot;: false}, &quot;exporting&quot;: {}, &quot;labels&quot;: {}, &quot;legend&quot;: {&quot;enabled&quot;: true}, &quot;loading&quot;: {}, &quot;navigation&quot;: {}, &quot;navigator&quot;: {}, &quot;plotOptions&quot;: {}, &quot;rangeSelector&quot;: {}, &quot;scrollbar&quot;: {}, &quot;series&quot;: {}, &quot;subtitle&quot;: {}, &quot;title&quot;: {&quot;text&quot;: &quot;Strategy 1&quot;}, &quot;tooltip&quot;: {}, &quot;xAxis&quot;: {&quot;type&quot;: &quot;datetime&quot;, &quot;labels&quot;: {&quot;step&quot;: 1, &quot;formatter&quot;: function () { return Highcharts.dateFormat(&#x27;%Y-%m-%d&#x27;, this.value); }}}, &quot;yAxis&quot;: [{&quot;height&quot;: &quot;100%&quot;, &quot;lineWidth&quot;: 2}]}; var chart = new Highcharts.StockChart(option); var data = [{&quot;data&quot;: [[1495756800000.0, 1265.05], [1496102400000.0, 1262.7], [1496188800000.0, 1266.2], [1496275200000.0, 1264.85], [1496361600000.0, 1274.95], [1496620800000.0, 1279.95], [1496707200000.0, 1293.5], [1496793600000.0, 1291.0], [1496880000000.0, 1273.1], [1496966400000.0, 1266.55], [1497225600000.0, 1266.4], [1497312000000.0, 1262.0], [1497398400000.0, 1275.5], [1497484800000.0, 1254.55], [1497571200000.0, 1255.4], [1497830400000.0, 1248.15], [1497916800000.0, 1242.2], [1498003200000.0, 1242.5], [1498089600000.0, 1250.8], [1498176000000.0, 1255.7], [1498435200000.0, 1245.25], [1498521600000.0, 1249.55], [1498608000000.0, 1248.0], [1498694400000.0, 1243.5], [1498780800000.0, 1242.25], [1499040000000.0, 1229.25], [1499126400000.0, 1223.75], [1499212800000.0, 1220.3], [1499299200000.0, 1224.9], [1499385600000.0, 1215.65], [1499644800000.0, 1211.9], [1499731200000.0, 1211.05], [1499817600000.0, 1218.8], [1499904000000.0, 1218.9], [1499990400000.0, 1230.3], [1500249600000.0, 1234.1], [1500336000000.0, 1240.75], [1500422400000.0, 1242.15], [1500508800000.0, 1238.7], [1500595200000.0, 1248.55], [1500854400000.0, 1255.55], [1500940800000.0, 1254.4], [1501027200000.0, 1248.1], [1501113600000.0, 1261.1], [1501200000000.0, 1264.9], [1501459200000.0, 1267.55], [1501545600000.0, 1270.95], [1501632000000.0, 1269.6], [1501718400000.0, 1268.1], [1501804800000.0, 1257.7], [1502064000000.0, 1258.0], [1502150400000.0, 1261.8], [1502236800000.0, 1271.05], [1502323200000.0, 1284.4], [1502409600000.0, 1286.1], [1502668800000.0, 1282.3], [1502755200000.0, 1270.3], [1502841600000.0, 1272.75], [1502928000000.0, 1285.15], [1503014400000.0, 1295.8], [1503273600000.0, 1292.9], [1503360000000.0, 1284.2], [1503446400000.0, 1286.65], [1503532800000.0, 1289.0], [1503619200000.0, 1285.3], [1503878400000.0, 1285.3], [1503964800000.0, 1318.65], [1504051200000.0, 1308.5], [1504137600000.0, 1311.75], [1504224000000.0, 1320.4], [150448320000 ...

# %%
me = Trader()
buy_open = []
sell_close = []
sell_open = []
buy_close = []
for i in range(1,len(xaus)):
    price = xaus[i]
    time = dates[i]
    pre_price = xaus[i-1]
    if model.predict(test_input.iloc[i:i+1,:])[0][0] > 0.5:
        # 觉得要涨
        if me.short_position > 0:
            # 如果有空仓，赶紧平
            me.buy_close(me.short_position,price,time)
            buy_close.append((time,price))
            print("I'am running away, bye!")
        else:
            print('I have no short position, take it easy.')
        # 然后开一仓
        me.buy_open(50, price, time)
        buy_open.append((time,price))
    else: # 反过来，如果觉得要跌了
        if me.long_position>0:
            # 如果有多仓，赶紧平
            me.sell_close(me.long_position,price,time)
            sell_close.append((time,price))
            print("I'am running away, bye!")
        else:
            print("I have no long position, take it easy")
        # 然后开新仓
        me.sell_open(50, price, time)
        sell_open.append((time,price))
    # if price>pre_price:
    #     if price<pre_price*0.98: # 如果涨幅达2%，平空仓，不开空仓，如果涨了但是不足2%，开多仓，不用平空仓
    #         print(str(time)+' price went up too high, stop shorting!')
    #         if me.short_position > 0:
    #             me.buy_close(me.short_position,price,time)
    #             print("I'am running away, bye!")
    #         else:
    #             print('I have no short position, take it easy.')
    #     else:
    #         me.buy_open(5, price, time)
    # else:
    #     if price>pre_price*1.02:# 如果跌幅达2%，平多仓，不开空仓，如果跌了但是不足2%，开空仓，不用平多仓
    #         print(str(time)+' price went up too low, stop longing!')
    #         if me.long_position>0:
    #             me.sell_close(me.long_position,price,time)
    #             print("I'am running away, bye!")
    #         else:
    #             print("I have no long position, take it easy")
    #     else:
    #         me.sell_open(5, price, time)
    me.settle(price, time)
# Out:
# 750.0000000028，所需保证金总额为150000
# Balance changed: 25500.0
# This day is over.
# I have no short position, take it easy.
# defaultUser在价格1279.8开多仓50手，现仓位为多200，空0，保证金账户余额为1318200.0000000028，所需保证金总额为200000
# Balance changed: -34500.0
# This day is over.
# defaultUser在价格1283.7平多仓200手，现仓位为多0，空0，保证金账户余额为1283700.0000000028，所需保证金总额为0
# I'am running away, bye!
# defaultUser在价格1283.7开空仓50手，现仓位为多0，空50，保证金账户余额为1283650.0000000028，所需保证金总额为50000
# Balance changed: 78000.0
# This day is over.
# I have no long position, take it easy
# defaultUser在价格1293.9开空仓50手，现仓位为多0，空100，保证金账户余额为1361600.0000000028，所需保证金总额为100000
# Balance changed: 51000.00000000186
# This day is over.
# I have no long position, take it easy
# defaultUser在价格1302.15开空仓50手，现仓位为多0，空150，保证金账户余额为1412550.0000000047，所需保证金总额为150000
# Balance changed: 82499.99999999627
# This day is over.
# I have no long position, take it easy
# defaultUser在价格1307.55开空仓50手，现仓位为多0，空200，保证金账户余额为1495000.000000001，所需保证金总额为200000
# Balance changed: 81000.0
# This day is over.
# defaultUser在价格1310.7平空仓200手，现仓位为多0，空0，保证金账户余额为1576000.000000001，所需保证金总额为0
# I'am running away, bye!
# defaultUser在价格1310.7开多仓50手，现仓位为多50，空0，保证金账户余额为1575950.000000001，所需保证金总额为50000
# Balance changed: 63000.0
# This day is over.
# defaultUser在价格1323.25平多仓50手，现仓位为多0，空0，保证金账户余额为1638950.000000001，所需保证金总额为0
# I'am running away, bye!
# defaultUser在价格1323.25开空仓50手，现仓位为多0，空50，保证金账户余额为1638900.000000001，所需保证金总额为50000
# Balance changed: 62750.0
# This day is over.
# defaultUser在价格1318.7平空仓50手，现仓位为多0，空0，保证金账户余额为1701650.000000001，所需保证金总额为0
# I'am running away, bye!
# defaultUser在价格1318.7开多仓50手，现仓位为多50，空0，保证金账户余额为1701600.000000001，所需保证金总额为50000
# Balance changed: -22750.0
# This day is over.
# I have no short position, take it easy.
# defaultUser在价格1312.15开多仓50手，现仓位为多100，空0，保证金账户余额为1678800.000000001，所需保证金总额为100000
# Balance changed: -32750.0
# This day is over.
# defaultUser在价格1314.2平多仓100手，现仓位为多0，空0，保证金账户余额为1646050.000000001，所需保证金总额为0
# I'am running away, bye!
# defaultUser在价格1314.2开空仓50手，现仓位为多0，空50，保证金账户余额为1646000.000000001，所需保证金总额为50000
# Balance changed: 20500.0
# This day is over.
# I have no long position, take it easy
# defaultUser在价格1312.4开空仓50手，现仓位为多0，空100，保证金账户余额为1666450.000000001，所需保证金总额为100000
# Balance changed: -9000.0
# This day is over.
# I have no long position, take it easy
# defaultUser在价格1310.0开空仓50手，现仓位为多0，空150，保证金账户余额为1657400.000000001，所需保证金总额为150000
# Balance changed: -24000.0
# This day is over.
# I have no long position, take it easy
# defaultUser在价格1314.85开空仓50手，现仓位为多0，空200，保证金账户余额为1633350.000000001，所需保证金总额为200000
# Balance changed: 72750.0
# This day is over.
# defaultUser在价格1306.4平空仓200手，现仓位为多0，空0，保证金账户余额为1706100.000000001，所需保证金总额为0
# I'am running away, bye!
# defaultUser在价格1306.4开多仓50手，现仓位为多50，空0，保证金账户余额为1706050.000000001，所需保证金总额为50000
# Balance changed: -168999.99999999627
# This day is over.
# defaultUser在价格1310.0平多仓50手，现仓位为多0，空0，保证金账户余额为1537050.0000000047，所需保证金总额为0
# I'am running away, bye!
# defaultUser在价格1310.0开空仓50手，现仓位为多0，空50，保证金账户余额为1537000.0000000047，所需保证金总额为50000
# Balance changed: 17999.99999999907
# This day is over.
# I have no long position, take it easy
# defaultUser在价格1312.8开空仓50手，现仓位为多0，空100，保证金账户余额为1554950.0000000037，所需保证金总额为100000
# Balance changed: 14000.0
# This day is over.
# I have no long position, take it easy
# defaultUser在价格1311.45开空仓50手，现仓位为多0，空150，保证金账户余额为1568900.0000000037，所需保证金总额为150000
# Balance changed: -13500.0
# This day is over.
# I have no long position, take it easy
# defaultUser在价格1316.55开空仓50手，现仓位为多0，空200，保证金账户余额为1555350.0000000037，所需保证金总额为200000
# Balance changed: 76500.0
# This day is over.
# I have no long position, take it easy
# defaultUser在价格1325.5开空仓50手，现仓位为多0，空250，保证金账户余额为1631800.0000000037，所需保证金总额为250000
# Balance changed: 179000.0
# This day is over.
# I have no long position, take it easy
# defaultUser在价格1334.15开空仓50手，现仓位为多0，空300，保证金账户余额为1810750.0000000037，所需保证金总额为300000
# Balance changed: 216250.0
# This day is over.
# I have no long position, take it easy
# defaultUser在价格1343.75开空仓50手，现仓位为多0，空350，保证金账户余额为2026950.0000000037，所需保证金总额为350000
# Balance changed: 288000.0
# This day is over.
# I have no long position, take it easy
# defaultUser在价格1331.25开空仓50手，现仓位为多0，空400，保证金账户余额为2314900.0000000037，所需保证金总额为400000
# Balance changed: -437500.0
# This day is over.
# defaultUser在价格1329.05平空仓400手，现仓位为多0，空0，保证金账户余额为1877400.0000000037，所需保证金总额为0
# I'am running away, bye!
# defaultUser在价格1329.05开多仓50手，现仓位为多50，空0，保证金账户余额为1877350.0000000037，所需保证金总额为50000
# Balance changed: -88000.0
# This day is over.
# defaultUser在价格1331.05平多仓50手，现仓位为多0，空0，保证金账户余额为1789350.0000000037，所需保证金总额为0
# I'am running away, bye!
# defaultUser在价格1331.05开空仓50手，现仓位为多0，空50，保证金账户余额为1789300.0000000037，所需保证金总额为50000
# Balance changed: 10000.0
# This day is over.
# defaultUser在价格1325.05平空仓50手，现仓位为多0，空0，保证金账户余额为1799300.0000000037，所需保证金总额为0
# I'am running away, bye!
# defaultUser在价格1325.05开多仓50手，现仓位为多50，空0，保证金账户余额为1799250.0000000037，所需保证金总额为50000
# Balance changed: -30000.0
# This day is over.
# I have no short position, take it easy.
# defaultUser在价格1322.85开多仓50手，现仓位为多100，空0，保证金账户余额为1769200.0000000037，所需保证金总额为100000
# Balance changed: -11000.0
# This day is over.
# I have no short position, take it easy.
# defaultUser在价格1319.15开多仓50手，现仓位为多150，空0，保证金账户余额为1758150.0000000037，所需保证金总额为150000
# Balance changed: -37000.0
# This day is over.
# I have no short position, take it easy.
# defaultUser在价格1311.95开多仓50手，现仓位为多200，空0，保证金账户余额为1721100.0000000037，所需保证金总额为200000
# Balance changed: -108000.0
# This day is over.
# I have no short position, take it easy.
# defaultUser在价格1285.4开多仓50手，现仓位为多250，空0，保证金账户余额为1613050.0000000037，所需保证金总额为250000
# Balance changed: -531000.0
# This day is over.
# I have no short position, take it easy.
# defaultUser在价格1283.8开多仓50手，现仓位为多300，空0，保证金账户余额为1082000.0000000037，所需保证金总额为300000
# Balance changed: -40000.0
# This day is over.
# defaultUser在价格1285.85平多仓300手，现仓位为多0，空0，保证金账户余额为1042000.0000000037，所需保证金总额为0
# I'am running away, bye!
# defaultUser在价格1285.85开空仓50手，现仓位为多0，空50，保证金账户余额为1041950.0000000037，所需保证金总额为50000
# Balance changed: 61500.0
# This day is over.
# defaultUser在价格1285.3平空仓50手，现仓位为多0，空0，保证金账户余额为1103450.0000000037，所需保证金总额为0
# I'am running away, bye!
# defaultUser在价格1285.3开多仓50手，现仓位为多50，空0，保证金账户余额为1103400.0000000037，所需保证金总额为50000
# Balance changed: -2749.9999999990687
# This day is over.
# defaultUser在价格1296.75平多仓50手，现仓位为多0，空0，保证金账户余额为1100650.0000000047，所需保证金总额为0
# I'am running away, bye!
# defaultUser在价格1296.75开空仓50手，现仓位为多0，空50，保证金账户余额为1100600.0000000047，所需保证金总额为50000
# Balance changed: 57250.0
# This day is over.
# I have no long position, take it easy
# defaultUser在价格1292.75开空仓50手，现仓位为多0，空100，保证金账户余额为1157800.0000000047，所需保证金总额为100000
# Balance changed: -20000.0
# This day is over.
# defaultUser在价格1297.05平空仓100手，现仓位为多0，空0，保证金账户余额为1137800.0000000047，所需保证金总额为0
# I'am running away, bye!
# defaultUser在价格1297.05开多仓50手，现仓位为多50，空0，保证金账户余额为1137750.0000000047，所需保证金总额为50000
# Balance changed: 43000.0
# This day is over.
# defaultUser在价格1306.95平多仓50手，现仓位为多0，空0，保证金账户余额为1180750.0000000047，所需保证金总额为0
# I'am running away, bye!
# defaultUser在价格1306.95开空仓50手，现仓位为多0，空50，保证金账户余额为1180700.0000000047，所需保证金总额为50000
# Balance changed: 49500.0
# This day is over.
# I have no long position, take it easy
# defaultUser在价格1295.55开空仓50手，现仓位为多0，空100，保证金账户余额为1230150.0000000047，所需保证金总额为100000
# Balance changed: -57000.0
# This day is over.
# I have no long position, take it easy
# defaultUser在价格1303.5开空仓50手，现仓位为多0，空150，保证金账户余额为1173100.0000000047，所需保证金总额为150000
# Balance changed: 79500.0
# This day is over.
# I have no long position, take it easy
# defaultUser在价格1305.6开空仓50手，现仓位为多0，空200，保证金账户余额为1252550.0000000047，所需保证金总额为200000
# Balance changed: 31499.999999996275
# This day is over.
# defaultUser在价格1307.7平空仓200手，现仓位为多0，空0，保证金账户余额为1284050.000000001，所需保证金总额为0
# I'am running away, bye!
# defaultUser在价格1307.7开多仓50手，现仓位为多50，空0，保证金账户余额为1284000.000000001，所需保证金总额为50000
# Balance changed: 42000.000000003725
# This day is over.
# I have no short position, take it easy.
# defaultUser在价格1303.7开多仓50手，现仓位为多100，空0，保证金账户余额为1325950.0000000047，所需保证金总额为100000
# Balance changed: -20000.0
# This day is over.
# defaultUser在价格1309.6平多仓100手，现仓位为多0，空0，保证金账户余额为1305950.0000000047，所需保证金总额为0
# I'am running away, bye!
# defaultUser在价格1309.6开空仓50手，现仓位为多0，空50，保证金账户余额为1305900.0000000047，所需保证金总额为50000
# Balance changed: 58999.99999999814
# This day is over.
# I have no long position, take it easy
# defaultUser在价格1311.3开空仓50手，现仓位为多0，空100，保证金账户余额为1364850.0000000028，所需保证金总额为100000
# Balance changed: 8500.0
# This day is over.
# I have no long position, take it easy
# defaultUser在价格1319.55开空仓50手，现仓位为多0，空150，保证金账户余额为1373300.0000000028，所需保证金总额为150000
# Balance changed: 82500.0
# This day is over.
# defaultUser在价格1316.3平空仓150手，现仓位为多0，空0，保证金账户余额为1455800.0000000028，所需保证金总额为0
# I'am running away, bye!
# defaultUser在价格1316.3开多仓50手，现仓位为多50，空0，保证金账户余额为1455750.0000000028，所需保证金总额为50000
# Balance changed: -48750.0
# This day is over.
# I have no short position, take it easy.
# defaultUser在价格1309.7开多仓50手，现仓位为多100，空0，保证金账户余额为1406950.0000000028，所需保证金总额为100000
# Balance changed: -33000.0
# This day is over.
# defaultUser在价格1295.15平多仓100手，现仓位为多0，空0，保证金账户余额为1373950.0000000028，所需保证金总额为0
# I'am running away, bye!
# defaultUser在价格1295.15开空仓50手，现仓位为多0，空50，保证金账户余额为1373900.0000000028，所需保证金总额为50000
# Balance changed: -145499.99999999814
# This day is over.
# I have no long position, take it easy
# defaultUser在价格1295.4开空仓50手，现仓位为多0，空100，保证金账户余额为1228350.0000000047，所需保证金总额为100000
# Balance changed: 1250.0
# This day is over.
# defaultUser在价格1293.5平空仓100手，现仓位为多0，空0，保证金账户余额为1229600.0000000047，所需保证金总额为0
# I'am running away, bye!
# defaultUser在价格1293.5开多仓50手，现仓位为多50，空0，保证金账户余额为1229550.0000000047，所需保证金总额为50000
# Balance changed: -19000.000000001863
# This day is over.
# I have no short position, take it easy.
# defaultUser在价格1290.3开多仓50手，现仓位为多100，空0，保证金账户余额为1210500.0000000028，所需保证金总额为100000
# Balance changed: -16000.0
# This day is over.
# defaultUser在价格1290.45平多仓100手，现仓位为多0，空0，保证金账户余额为1194500.0000000028，所需保证金总额为0
# I'am running away, bye!
# defaultUser在价格1290.45开空仓50手，现仓位为多0，空50，保证金账户余额为1194450.0000000028，所需保证金总额为50000
# Balance changed: 1500.0
# This day is over.
# defaultUser在价格1283.15平空仓50手，现仓位为多0，空0，保证金账户余额为1195950.0000000028，所需保证金总额为0
# I'am running away, bye!
# defaultUser在价格1283.15开多仓50手，现仓位为多50，空0，保证金账户余额为1195900.0000000028，所需保证金总额为50000
# Balance changed: -36499.99999999907
# This day is over.
# defaultUser在价格1288.45平多仓50手，现仓位为多0，空0，保证金账户余额为1159400.0000000037，所需保证金总额为0
# I'am running away, bye!
# defaultUser在价格1288.45开空仓50手，现仓位为多0，空50，保证金账户余额为1159350.0000000037，所需保证金总额为50000
# Balance changed: 26499.99999999907
# This day is over.
# defaultUser在价格1300.0平空仓50手，现仓位为多0，空0，保证金账户余额为1185850.0000000028，所需保证金总额为0
# I'am running away, bye!
# defaultUser在价格1300.0开多仓50手，现仓位为多50，空0，保证金账户余额为1185800.0000000028，所需保证金总额为50000
# Balance changed: 57750.0
# This day is over.
# defaultUser在价格1303.0平多仓50手，现仓位为多0，空0，保证金账户余额为1243550.0000000028，所需保证金总额为0
# I'am running away, bye!
# defaultUser在价格1303.0开空仓50手，现仓位为多0，空50，保证金账户余额为1243500.0000000028，所需保证金总额为50000
# Balance changed: 15000.0
# This day is over.
# defaultUser在价格1305.45平空仓50手，现仓位为多0，空0，保证金账户余额为1258500.0000000028，所需保证金总额为0
# I'am running away, bye!
# defaultUser在价格1305.45开多仓50手，现仓位为多50，空0，保证金账户余额为1258450.0000000028，所需保证金总额为50000
# Balance changed: 12250.0
# This day is over.
# I have no short position, take it easy.
# defaultUser在价格1298.8开多仓50手，现仓位为多100，空0，保证金账户余额为1270650.0000000028，所需保证金总额为100000
# Balance changed: -33250.0
# This day is over.
# I have no short position, take it easy.
# defaultUser在价格1294.3开多仓50手，现仓位为多150，空0，保证金账户余额为1237350.0000000028，所需保证金总额为150000
# Balance changed: -45000.0
# This day is over.
# I have no short position, take it easy.
# defaultUser在价格1285.65开多仓50手，现仓位为多200，空0，保证金账户余额为1192300.0000000028，所需保证金总额为200000
# Balance changed: -129749.99999999627
# This day is over.
# defaultUser在价格1276.35平多仓200手，现仓位为多0，空0，保证金账户余额为1062550.0000000065，所需保证金总额为0
# I'am running away, bye!
# defaultUser在价格1276.35开空仓50手，现仓位为多0，空50，保证金账户余额为1062500.0000000065，所需保证金总额为50000
# Balance changed: -186000.00000000745
# This day is over.
# defaultUser在价格1275.85平空仓50手，现仓位为多0，空0，保证金账户余额为876499.9999999991，所需保证金总额为0
# I'am running away, bye!
# defaultUser在价格1275.85开多仓50手，现仓位为多50，空0，保证金账户余额为876449.9999999991，所需保证金总额为50000
# Balance changed: -2500.0
# This day is over.
# I have no short position, take it easy.
# defaultUser在价格1275.7开多仓50手，现仓位为多100，空0，保证金账户余额为873899.9999999991，所需保证金总额为100000
# Balance changed: -750.0
# This day is over.
# defaultUser在价格1275.7平多仓100手，现仓位为多0，空0，保证金账户余额为873149.9999999991，所需保证金总额为0
# I'am running away, bye!
# defaultUser在价格1275.7开空仓50手，现仓位为多0，空50，保证金账户余额为873099.9999999991，所需保证金总额为50000
# Balance changed: 0.0
# This day is over.
# defaultUser在价格1269.5平空仓50手，现仓位为多0，空0，保证金账户余额为873099.9999999991，所需保证金总额为0
# I'am running away, bye!
# defaultUser在价格1269.5开多仓50手，现仓位为多50，空0，保证金账户余额为873049.9999999991，所需保证金总额为50000
# Balance changed: -31000.0
# This day is over.
# defaultUser在价格1271.65平多仓50手，现仓位为多0，空0，保证金账户余额为842049.9999999991，所需保证金总额为0
# I'am running away, bye!
# defaultUser在价格1271.65开空仓50手，现仓位为多0，空50，保证金账户余额为841999.9999999991，所需保证金总额为50000
# Balance changed: 10750.000000000931
# This day is over.
# I have no long position, take it easy
# defaultUser在价格1280.8开空仓50手，现仓位为多0，空100，保证金账户余额为852700.0，所需保证金总额为100000
# Balance changed: 45750.0
# This day is over.
# I have no long position, take it easy
# defaultUser在价格1284.2开空仓50手，现仓位为多0，空150，保证金账户余额为898400.0，所需保证金总额为150000
# Balance changed: 34000.0
# This day is over.
# defaultUser在价格1279.5平空仓150手，现仓位为多0，空0，保证金账户余额为932400.0，所需保证金总额为0
# I'am running away, bye!
# defaultUser在价格1279.5开多仓50手，现仓位为多50，空0，保证金账户余额为932350.0，所需保证金总额为50000
# Balance changed: -70500.0
# This day is over.
# defaultUser在价格1282.3平多仓50手，现仓位为多0，空0，保证金账户余额为861850.0，所需保证金总额为0
# I'am running away, bye!
# defaultUser在价格1282.3开空仓50手，现仓位为多0，空50，保证金账户余额为861800.0，所需保证金总额为50000
# Balance changed: 14000.0
# This day is over.
# I have no long position, take it easy
# defaultUser在价格1283.8开空仓50手，现仓位为多0，空100，保证金账户余额为875750.0，所需保证金总额为100000
# Balance changed: 7500.0
# This day is over.
# defaultUser在价格1270.95平空仓100手，现仓位为多0，空0，保证金账户余额为883250.0，所需保证金总额为0
# I'am running away, bye!
# defaultUser在价格1270.95开多仓50手，现仓位为多50，空0，保证金账户余额为883200.0，所需保证金总额为50000
# Balance changed: -128500.0
# This day is over.
# defaultUser在价格1278.55平多仓50手，现仓位为多0，空0，保证金账户余额为754700.0，所需保证金总额为0
# I'am running away, bye!
# defaultUser在价格1278.55开空仓50手，现仓位为多0，空50，保证金账户余额为754650.0，所需保证金总额为50000
# Balance changed: 38000.0
# This day is over.
# defaultUser在价格1278.55平空仓50手，现仓位为多0，空0，保证金账户余额为792650.0，所需保证金总额为0
# I'am running away, bye!
# defaultUser在价格1278.55开多仓50手，现仓位为多50，空0，保证金账户余额为792600.0，所需保证金总额为50000
# Balance changed: 0.0
# This day is over.
# defaultUser在价格1281.2平多仓50手，现仓位为多0，空0，保证金账户余额为792600.0，所需保证金总额为0
# I'am running away, bye!
# defaultUser在价格1281.2开空仓50手，现仓位为多0，空50，保证金账户余额为792550.0，所需保证金总额为50000
# Balance changed: 13250.0
# This day is over.
# I have no long position, take it easy
# defaultUser在价格1285.2开空仓50手，现仓位为多0，空100，保证金账户余额为805750.0，所需保证金总额为100000
# Balance changed: 20000.0
# This day is over.
# defaultUser在价格1286.1平空仓100手，现仓位为多0，空0，保证金账户余额为825750.0，所需保证金总额为0
# I'am running away, bye!
# defaultUser在价格1286.1开多仓50手，现仓位为多50，空0，保证金账户余额为825700.0，所需保证金总额为50000
# Balance changed: 8999.999999998137
# This day is over.
# defaultUser在价格1287.1平多仓50手，现仓位为多0，空0，保证金账户余额为834699.9999999981，所需保证金总额为0
# I'am running away, bye!
# defaultUser在价格1287.1开空仓50手，现仓位为多0，空50，保证金账户余额为834649.9999999981，所需保证金总额为50000
# Balance changed: 5000.0
# This day is over.
# I have no long position, take it easy
# defaultUser在价格1295.6开空仓50手，现仓位为多0，空100，保证金账户余额为839599.9999999981，所需保证金总额为100000
# Balance changed: 42500.0
# This day is over.
# I have no long position, take it easy
# defaultUser在价格1298.4开空仓50手，现仓位为多0，空150，保证金账户余额为882049.9999999981，所需保证金总额为150000
# Balance changed: 28000.0
# This day is over.
# I have no long position, take it easy
# defaultUser在价格1299.1开空仓50手，现仓位为多0，空200，保证金账户余额为909999.9999999981，所需保证金总额为200000
# Balance changed: 10499.999999996275
# This day is over.
# defaultUser在价格1291.7平空仓200手，现仓位为多0，空0，保证金账户余额为920499.9999999944，所需保证金总额为0
# I'am running away, bye!
# defaultUser在价格1291.7开多仓50手，现仓位为多50，空0，保证金账户余额为920449.9999999944，所需保证金总额为50000
# Balance changed: -147999.99999999627
# This day is over.
# I have no short position, take it easy.
# defaultUser在价格1280.8开多仓50手，现仓位为多100，空0，保证金账户余额为772399.9999999981，所需保证金总额为100000
# Balance changed: -54500.0
# This day is over.
# defaultUser在价格1276.85平多仓100手，现仓位为多0，空0，保证金账户余额为717899.9999999981，所需保证金总额为0
# I'am running away, bye!
# defaultUser在价格1276.85开空仓50手，现仓位为多0，空50，保证金账户余额为717849.9999999981，所需保证金总额为50000
# Balance changed: -39500.00000000186
# This day is over.
# I have no long position, take it easy
# defaultUser在价格1271.15开空仓50手，现仓位为多0，空100，保证金账户余额为678299.9999999963，所需保证金总额为100000
# Balance changed: -28499.999999998137
# This day is over.
# I have no long position, take it easy
# defaultUser在价格1273.8开空仓50手，现仓位为多0，空150，保证金账户余额为649749.9999999981，所需保证金总额为150000
# Balance changed: 26500.0
# This day is over.
# I have no long position, take it easy
# defaultUser在价格1283.65开空仓50手，现仓位为多0，空200，保证金账户余额为676199.9999999981，所需保证金总额为200000
# Balance changed: 147750.00000000373
# This day is over.
# I have no long position, take it easy
# defaultUser在价格1282.5开空仓50手，现仓位为多0，空250，保证金账户余额为823900.0000000019，所需保证金总额为250000
# Balance changed: -23000.000000003725
# This day is over.
# defaultUser在价格1278.3平空仓250手，现仓位为多0，空0，保证金账户余额为800899.9999999981，所需保证金总额为0
# I'am running away, bye!
# defaultUser在价格1278.3开多仓50手，现仓位为多50，空0，保证金账户余额为800849.9999999981，所需保证金总额为50000
# Balance changed: -105000.0
# This day is over.
# defaultUser在价格1281.65平多仓50手，现仓位为多0，空0，保证金账户余额为695849.9999999981，所需保证金总额为0
# I'am running away, bye!
# defaultUser在价格1281.65开空仓50手，现仓位为多0，空50，保证金账户余额为695799.9999999981，所需保证金总额为50000
# Balance changed: 16750.00000000093
# This day is over.
# defaultUser在价格1280.95平空仓50手，现仓位为多0，空0，保证金账户余额为712549.9999999991，所需保证金总额为0
# I'am running away, bye!
# defaultUser在价格1280.95开多仓50手，现仓位为多50，空0，保证金账户余额为712499.9999999991，所需保证金总额为50000
# Balance changed: -3500.0000000009313
# This day is over.
# defaultUser在价格1295.55平多仓50手，现仓位为多0，空0，保证金账户余额为708999.9999999981，所需保证金总额为0
# I'am running away, bye!
# defaultUser在价格1295.55开空仓50手，现仓位为多0，空50，保证金账户余额为708949.9999999981，所需保证金总额为50000
# Balance changed: 73000.0
# This day is over.
# I have no long position, take it easy
# defaultUser在价格1317.1开空仓50手，现仓位为多0，空100，保证金账户余额为781899.9999999981，所需保证金总额为100000
# Balance changed: 107750.0
# This day is over.
# I have no long position, take it easy
# defaultUser在价格1324.25开空仓50手，现仓位为多0，空150，保证金账户余额为889599.9999999981，所需保证金总额为150000
# Balance changed: 71500.0
# This day is over.
# I have no long position, take it easy
# defaultUser在价格1335.05开空仓50手，现仓位为多0，空200，保证金账户余额为961049.9999999981，所需保证金总额为200000
# Balance changed: 162000.0
# This day is over.
# I have no long position, take it easy
# defaultUser在价格1335.5开空仓50手，现仓位为多0，空250，保证金账户余额为1122999.9999999981，所需保证金总额为250000
# Balance changed: 9000.0
# This day is over.
# defaultUser在价格1340.65平空仓250手，现仓位为多0，空0，保证金账户余额为1131999.9999999981，所需保证金总额为0
# I'am running away, bye!
# defaultUser在价格1340.65开多仓50手，现仓位为多50，空0，保证金账户余额为1131949.9999999981，所需保证金总额为50000
# Balance changed: 128750.0
# This day is over.
# I have no short position, take it easy.
# defaultUser在价格1328.6开多仓50手，现仓位为多100，空0，保证金账户余额为1260649.9999999981，所需保证金总额为100000
# Balance changed: -60250.0
# This day is over.
# defaultUser在价格1324.3平多仓100手，现仓位为多0，空0，保证金账户余额为1200399.9999999981，所需保证金总额为0
# I'am running away, bye!
# defaultUser在价格1324.3开空仓50手，现仓位为多0，空50，保证金账户余额为1200349.9999999981，所需保证金总额为50000
# Balance changed: -43000.0
# This day is over.
# I have no long position, take it easy
# defaultUser在价格1332.35开空仓50手，现仓位为多0，空100，保证金账户余额为1157299.9999999981，所需保证金总额为100000
# Balance changed: 40250.0
# This day is over.
# I have no long position, take it easy
# defaultUser在价格1335.9开空仓50手，现仓位为多0，空150，保证金账户余额为1197499.9999999981，所需保证金总额为150000
# Balance changed: 35500.0
# This day is over.
# I have no long position, take it easy
# defaultUser在价格1351.25开空仓50手，现仓位为多0，空200，保证金账户余额为1232949.9999999981，所需保证金总额为200000
# Balance changed: 230250.0
# This day is over.
# I have no long position, take it easy
# defaultUser在价格1341.3开空仓50手，现仓位为多0，空250，保证金账户余额为1463149.9999999981，所需保证金总额为250000
# Balance changed: -199000.0
# This day is over.
# I have no long position, take it easy
# defaultUser在价格1341.35开空仓50手，现仓位为多0，空300，保证金账户余额为1264099.9999999981，所需保证金总额为300000
# Balance changed: 1250.0
# This day is over.
# I have no long position, take it easy
# defaultUser在价格1344.05开空仓50手，现仓位为多0，空350，保证金账户余额为1265299.9999999981，所需保证金总额为350000
# Balance changed: 81000.0
# This day is over.
# I have no long position, take it easy
# defaultUser在价格1379.5开空仓50手，现仓位为多0，空400，保证金账户余额为1346249.9999999981，所需保证金总额为400000
# Balance changed: 1240750.0
# This day is over.

# %%
The_Graph.add_data_set(buy_open, series_type='scatter',name='Buy_open', marker={'enabled': True, 'radius':5, 'symbol':'triangle'},color="red")
The_Graph.add_data_set(sell_close, series_type='scatter',name='Sell_close', marker={'enabled': True, 'radius':5, 'symbol':'triangle-down'},color="red")
The_Graph.add_data_set(sell_open, series_type='scatter',name='Sell_open', marker={'enabled': True, 'radius':5, 'symbol':'triangle-down'},color="green")
The_Graph.add_data_set(buy_close, series_type='scatter',name='Buy_close', marker={'enabled': True, 'radius':5, 'symbol':'triangle'},color="green")
The_Graph
# Out:
# <iframe style="border:0;outline:none;overflow:hidden" srcdoc="&lt;!DOCTYPE html&gt; &lt;html lang=&quot;en&quot;&gt; &lt;head&gt; &lt;meta charset=&quot;utf-8&quot; /&gt; &lt;link href=&quot;https://www.highcharts.com/highslide/highslide.css&quot; rel=&quot;stylesheet&quot; /&gt; &lt;script type=&quot;text/javascript&quot; src=&quot;https://ajax.googleapis.com/ajax/libs/jquery/1.9.1/jquery.min.js&quot;&gt;&lt;/script&gt; &lt;script type=&quot;text/javascript&quot; src=&quot;https://code.highcharts.com/stock/6/highstock.js&quot;&gt;&lt;/script&gt; &lt;script type=&quot;text/javascript&quot; src=&quot;https://code.highcharts.com/stock/6/modules/exporting.js&quot;&gt;&lt;/script&gt; &lt;script type=&quot;text/javascript&quot; src=&quot;https://code.highcharts.com/6/highcharts-more.js&quot;&gt;&lt;/script&gt; &lt;/head&gt; &lt;body style=&quot;margin:0;padding:0&quot;&gt; &lt;div id=&quot;container&quot; style=&quot;width:1000px;height:600px;&quot;&gt;Loading....&lt;/div&gt; &lt;script&gt; $(function(){ Highcharts.setOptions({&quot;global&quot;: {}, &quot;lang&quot;: {}}); var option = {&quot;chart&quot;: {&quot;renderTo&quot;: &quot;container&quot;, &quot;width&quot;: 1000, &quot;height&quot;: 600}, &quot;colors&quot;: {}, &quot;credits&quot;: {&quot;enabled&quot;: false}, &quot;exporting&quot;: {}, &quot;labels&quot;: {}, &quot;legend&quot;: {&quot;enabled&quot;: true}, &quot;loading&quot;: {}, &quot;navigation&quot;: {}, &quot;navigator&quot;: {}, &quot;plotOptions&quot;: {}, &quot;rangeSelector&quot;: {}, &quot;scrollbar&quot;: {}, &quot;series&quot;: {}, &quot;subtitle&quot;: {}, &quot;title&quot;: {&quot;text&quot;: &quot;Strategy 1&quot;}, &quot;tooltip&quot;: {}, &quot;xAxis&quot;: {&quot;type&quot;: &quot;datetime&quot;, &quot;labels&quot;: {&quot;step&quot;: 1, &quot;formatter&quot;: function () { return Highcharts.dateFormat(&#x27;%Y-%m-%d&#x27;, this.value); }}}, &quot;yAxis&quot;: [{&quot;height&quot;: &quot;100%&quot;, &quot;lineWidth&quot;: 2}]}; var chart = new Highcharts.StockChart(option); var data = [{&quot;data&quot;: [[1495756800000.0, 1265.05], [1496102400000.0, 1262.7], [1496188800000.0, 1266.2], [1496275200000.0, 1264.85], [1496361600000.0, 1274.95], [1496620800000.0, 1279.95], [1496707200000.0, 1293.5], [1496793600000.0, 1291.0], [1496880000000.0, 1273.1], [1496966400000.0, 1266.55], [1497225600000.0, 1266.4], [1497312000000.0, 1262.0], [1497398400000.0, 1275.5], [1497484800000.0, 1254.55], [1497571200000.0, 1255.4], [1497830400000.0, 1248.15], [1497916800000.0, 1242.2], [1498003200000.0, 1242.5], [1498089600000.0, 1250.8], [1498176000000.0, 1255.7], [1498435200000.0, 1245.25], [1498521600000.0, 1249.55], [1498608000000.0, 1248.0], [1498694400000.0, 1243.5], [1498780800000.0, 1242.25], [1499040000000.0, 1229.25], [1499126400000.0, 1223.75], [1499212800000.0, 1220.3], [1499299200000.0, 1224.9], [1499385600000.0, 1215.65], [1499644800000.0, 1211.9], [1499731200000.0, 1211.05], [1499817600000.0, 1218.8], [1499904000000.0, 1218.9], [1499990400000.0, 1230.3], [1500249600000.0, 1234.1], [1500336000000.0, 1240.75], [1500422400000.0, 1242.15], [1500508800000.0, 1238.7], [1500595200000.0, 1248.55], [1500854400000.0, 1255.55], [1500940800000.0, 1254.4], [1501027200000.0, 1248.1], [1501113600000.0, 1261.1], [1501200000000.0, 1264.9], [1501459200000.0, 1267.55], [1501545600000.0, 1270.95], [1501632000000.0, 1269.6], [1501718400000.0, 1268.1], [1501804800000.0, 1257.7], [1502064000000.0, 1258.0], [1502150400000.0, 1261.8], [1502236800000.0, 1271.05], [1502323200000.0, 1284.4], [1502409600000.0, 1286.1], [1502668800000.0, 1282.3], [1502755200000.0, 1270.3], [1502841600000.0, 1272.75], [1502928000000.0, 1285.15], [1503014400000.0, 1295.8], [1503273600000.0, 1292.9], [1503360000000.0, 1284.2], [1503446400000.0, 1286.65], [1503532800000.0, 1289.0], [1503619200000.0, 1285.3], [1503878400000.0, 1285.3], [1503964800000.0, 1318.65], [1504051200000.0, 1308.5], [1504137600000.0, 1311.75], [1504224000000.0, 1320.4], [150448320000 ...

# %%
me.records.to_csv('records_4nn_1.csv', index=False)

# %% [markdown]
# ### 错误pattern分析，从概率上，错几个后，再错的概率；实际值与预测值的差值，多个模型如何选择；
# ### 策略弥补错误
# ### 多个策略，可用的，算一下评价指标
