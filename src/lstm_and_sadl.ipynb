# %%
# import packages
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from itertools import chain
df = pd.read_csv('../res/input0130.csv')

# %%
scaler = StandardScaler()
starter = range(240,len(df)-1000,10)
all_results = []
all_evas = []
y_pred_clf = []
all_x_train = []
all_x_test = []
all_y_train = []
all_y_test = []
for train_begin in starter:
    train_end = train_begin + 750
    test_end = train_end + 250
    train_set = df[{'log_r','label'}][train_begin:train_end].reset_index()
    x_train, y_train = [], []
    x_train_set = list(chain.from_iterable(scaler.fit_transform(train_set['log_r'].values.reshape(-1,1))))
    for i in range(240,len(x_train_set)):
        x_train.append(x_train_set[i-240:i])
        y_train.append(train_set['label'][i])
    x_train, y_train = np.array(x_train), np.array(y_train)
    x_train = np.reshape(x_train, (x_train.shape[0],x_train.shape[1],1)) 
    
    # model = lstm_model()
    # model.fit(x_train,y_train,epochs=100,callbacks=[EarlyStopping(monitor='loss',patience=10)])

    x_test, y_test = [], []
    test_set = df[{'log_r','label'}][train_end-240:test_end].reset_index()
    x_test_set = list(chain.from_iterable(scaler.transform(test_set['log_r'].values.reshape(-1,1))))
    for i in range(240,len(x_test_set)):
        x_test.append(x_test_set[i-240:i])
        y_test.append(test_set['label'][i])
    x_test, y_test = np.array(x_test), np.array(y_test)
    x_test = np.reshape(x_test, (x_test.shape[0],x_test.shape[1],1)) 
    all_x_train.append(x_train)
    all_y_train.append(y_train)
    all_x_test.append(x_test)
    all_y_test.append(y_test)

    # all_results.append(model.predict(x_test))
    # all_evas.append(model.evaluate(x_test, y_test))
    # y_pred_clf.append(model.predict_classes(x_test))

# %%
from tqdm import tqdm
from keras.models import load_model, Model
from sa import *
from utils import *
# Out:
# Using TensorFlow backend.

# %%
model = load_model('lstm_r_1c.h5')
default_upper_bound = 2000
default_n_bucket = 1000
default_n_classes = 2
class Args(): #创建一个类
    def __init__(self): #定义初始化信息。
        self.is_classification = True
        self.save_path = './tmp/'
        self.d = 'lstm_r'
        self.num_classes = 2
        self.lsa = True
        self.dsa = True
        self.target = 'none'
        self.batch_size = 128
        self.var_threshold = 1e-5
        self.upper_bound = 2000
        self.n_bucket = 1000
        self.is_classification = True
args = Args()
model.summary()
# Out:
# WARNING:tensorflow:From D:\Anaconda3\envs\inno\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 50)                10400
# _________________________________________________________________
# activation_1 (Activation)    (None, 50)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 102
# =================================================================
# Total params: 10,502
# Trainable params: 10,502
# Non-trainable params: 0
# _________________________________________________________________

# %%
layer_names = ['activation_1']

# %%
num=0
test_auc = []
test_cov = []
test_lsa = fetch_lsa(model, x_train, x_test, "test", layer_names, args)
for x_test in all_x_test:
    num=num+1
    target_lsa = fetch_lsa(model, x_train, x_test, str(num), layer_names, args)
    # target_lsa = fetch_lsa(model, x_train, x_target, args.target, layer_names, args)
    target_cov = get_sc(
        np.amin(target_lsa), default_upper_bound, default_n_bucket, target_lsa
    )

    auc = compute_roc_auc(test_lsa, target_lsa, 10)
    test_auc.append(auc)
    test_cov.append(target_cov)
    print(infog("ROC-AUC: " + str(auc * 100)))

    print(infog("LSA coverage: " + str(target_cov)))
    if num >= 164:
        break
# Out:
# 18.91it/s]ROC-AUC: 82.99479166666667
# LSA coverage: 8.4
# Found saved train ATs, skip serving
# Found saved 104 ATs, skip serving
# The number of removed columns: 0
# [104] Fetching LSA
#
# kde: 100%|██████████| 2/2 [00:00<00:00, 402.47it/s]
# 100%|██████████| 250/250 [00:00<00:00, 3133.30it/s]ROC-AUC: 81.57899305555554
# LSA coverage: 7.000000000000001
# Found saved train ATs, skip serving
# Found saved 105 ATs, skip serving
# The number of removed columns: 0
# [105] Fetching LSA
#
# kde: 100%|██████████| 2/2 [00:00<00:00, 501.38it/s]
# 100%|██████████| 250/250 [00:00<00:00, 3528.85it/s]ROC-AUC: 89.8732638888889
# LSA coverage: 7.1
# Found saved train ATs, skip serving
# Found saved 106 ATs, skip serving
# The number of removed columns: 0
# [106] Fetching LSA
#
# kde: 100%|██████████| 2/2 [00:00<00:00, 334.22it/s]
# 100%|██████████| 250/250 [00:00<00:00, 2984.12it/s]ROC-AUC: 90.05468750000001
# LSA coverage: 5.6000000000000005
# Found saved train ATs, skip serving
# Found saved 107 ATs, skip serving
# The number of removed columns: 0
# [107] Fetching LSA
#
# kde: 100%|██████████| 2/2 [00:00<00:00, 501.47it/s]
# 100%|██████████| 250/250 [00:00<00:00, 3133.41it/s]ROC-AUC: 92.46180555555556
# LSA coverage: 5.4
# Found saved train ATs, skip serving
# Found saved 108 ATs, skip serving
# The number of removed columns: 0
# [108] Fetching LSA
#
# kde: 100%|██████████| 2/2 [00:00<00:00, 501.41it/s]
# 100%|██████████| 250/250 [00:00<00:00, 3298.27it/s]ROC-AUC: 91.48784722222221
# LSA coverage: 5.8999999999999995
# Found saved train ATs, skip serving
# Found saved 109 ATs, skip serving
# The number of removed columns: 0
# [109] Fetching LSA
#
# kde: 100%|██████████| 2/2 [00:00<00:00, 403.32it/s]
# 100%|██████████| 250/250 [00:00<00:00, 3255.42it/s]ROC-AUC: 91.06944444444444
# LSA coverage: 6.3
# Found saved train ATs, skip serving
# Found saved 110 ATs, skip serving
# The number of removed columns: 0
# [110] Fetching LSA
#
# kde: 100%|██████████| 2/2 [00:00<00:00, 505.31it/s]
# 100%|██████████| 250/250 [00:00<00:00, 3387.43it/s]ROC-AUC: 90.86111111111111
# LSA coverage: 6.5
# Found saved train ATs, skip serving
# Found saved 111 ATs, skip serving
# The number of removed columns: 0
# [111] Fetching LSA
#
# kde: 100%|██████████| 2/2 [00:00<00:00, 501.35it/s]
# 100%|██████████| 250/250 [00:00<00:00, 3133.38it/s]ROC-AUC: 89.7265625
# LSA coverage: 6.5
# Found saved train ATs, skip serving
# Found saved 112 ATs, skip serving
# The number of removed columns: 0
# [112] Fetching LSA
#
# kde: 100%|██████████| 2/2 [00:00<00:00, 401.04it/s]
# 100%|██████████| 250/250 [00:00<00:00, 3342.27it/s]ROC-AUC: 90.74305555555556
# LSA coverage: 5.5
# Found saved train ATs, skip serving
# Found saved 113 ATs, skip serving
# The number of removed columns: 0
# [113] Fetching LSA
#
# kde: 100%|██████████| 2/2 [00:00<00:00, 501.29it/s]
# 100%|██████████| 250/250 [00:00<00:00, 2880.24it/s]ROC-AUC: 91.30815972222221
# LSA coverage: 5.1
# Found saved train ATs, skip serving
# Found saved 114 ATs, skip serving
# The number of removed columns: 0
# [114] Fetching LSA
#
# kde: 100%|██████████| 2/2 [00:00<00:00, 501.41it/s]
# 100%|██████████| 250/250 [00:00<00:00, 3298.25it/s]ROC-AUC: 90.36284722222221
# LSA coverage: 4.1000000000000005
# Found saved train ATs, skip serving
# Found saved 115 ATs, skip serving
# The number of removed columns: 0
# [115] Fetching LSA
#
# kde: 100%|██████████| 2/2 [00:00<00:00, 501.35it/s]
# 100%|██████████| 250/250 [00:00<00:00, 3741.31it/s]ROC-AUC: 92.52083333333333
# LSA coverage: 3.4000000000000004
# Found saved train ATs, skip serving
# Found saved 116 ATs, skip serving
# The number of removed columns: 0
# [116] Fetching LSA
#
# kde: 100%|██████████| 2/2 [00:00<00:00, 334.29it/s]
# 100%|██████████| 250/250 [00:00<00:00, 3581.01it/s]ROC-AUC: 80.625
# LSA coverage: 2.3
# Found saved train ATs, skip serving
# Found saved 117 ATs, skip serving
# The number of removed columns: 0
# [117] Fetching LSA
#
# kde: 100%|██████████| 2/2 [00:00<00:00, 501.38it/s]
# 100%|██████████| 250/250 [00:00<00:00, 3341.19it/s]ROC-AUC: 92.48958333333333
# LSA coverage: 2.7
# Found saved train ATs, skip serving
# Found saved 118 ATs, skip serving
# The number of removed columns: 0
# [118] Fetching LSA
#
# kde: 100%|██████████| 2/2 [00:00<00:00, 501.35it/s]
# 100%|██████████| 250/250 [00:00<00:00, 3298.26it/s]ROC-AUC: 95.43229166666667
# LSA coverage: 3.1
# Found saved train ATs, skip serving
# Found saved 119 ATs, skip serving
# The number of removed columns: 0
# [119] Fetching LSA
#
# kde: 100%|██████████| 2/2 [00:00<00:00, 501.35it/s]
# 100%|██████████| 250/250 [00:00<00:00, 3298.38it/s]ROC-AUC: 94.98784722222223
# LSA coverage: 3.4000000000000004
# Found saved train ATs, skip serving
# Found saved 120 ATs, skip serving
# The number of removed columns: 0
# [120] Fetching LSA
#
# kde: 100%|██████████| 2/2 [00:00<00:00, 668.52it/s]
# 100%|██████████| 250/250 [00:00<00:00, 3342.23it/s]ROC-AUC: 93.37760416666666
# LSA coverage: 3.8
# Found saved train ATs, skip serving
# Found saved 121 ATs, skip serving
# The number of removed columns: 0
# [121] Fetching LSA
#
# kde: 100%|██████████| 2/2 [00:00<00:00, 401.04it/s]
# 100%|██████████| 250/250 [00:00<00:00, 3094.70it/s]ROC-AUC: 93.66927083333333
# LSA coverage: 4.5
# Found saved train ATs, skip serving
# Found saved 122 ATs, skip serving
# The number of removed columns: 0
# [122] Fetching LSA
#
# kde: 100%|██████████| 2/2 [00:00<00:00, 401.06it/s]
# 100%|██████████| 250/250 [00:00<00:00, 3298.29it/s]ROC-AUC: 91.59288194444444
# LSA coverage: 5.1
# Found saved train ATs, skip serving
# Found saved 123 ATs, skip serving
# The number of removed columns: 0
# [123] Fetching LSA
#
# kde: 100%|██████████| 2/2 [00:00<00:00, 501.38it/s]
# 100%|██████████| 250/250 [00:00<00:00, 3481.50it/s]ROC-AUC: 88.17881944444444
# LSA coverage: 5.8999999999999995
# Found saved train ATs, skip serving
# Found saved 124 ATs, skip serving
# The number of removed columns: 0
# [124] Fetching LSA
#
# kde: 100%|██████████| 2/2 [00:00<00:00, 501.38it/s]
# 100%|██████████| 250/250 [00:00<00:00, 3342.25it/s]ROC-AUC: 81.06076388888889
# LSA coverage: 6.3
# Found saved train ATs, skip serving
# Found saved 125 ATs, skip serving
# The number of removed columns: 0
# [125] Fetching LSA
#
# kde: 100%|██████████| 2/2 [00:00<00:00, 668.41it/s]
# 100%|██████████| 250/250 [00:00<00:00, 3481.43it/s]ROC-AUC: 78.91319444444444
# LSA coverage: 5.6000000000000005
# Found saved train ATs, skip serving
# Found saved 126 ATs, skip serving
# The number of removed columns: 0
# [126] Fetching LSA
#
# kde: 100%|██████████| 2/2 [00:00<00:00, 668.41it/s]
# 100%|██████████| 250/250 [00:00<00:00, 3433.71it/s]ROC-AUC: 74.01041666666667
# LSA coverage: 5.1
# Found saved train ATs, skip serving
# Found saved 127 ATs, skip serving
# The number of removed columns: 0
# [127] Fetching LSA
#
# kde: 100%|██████████| 2/2 [00:00<00:00, 400.97it/s]
# 100%|██████████| 250/250 [00:00<00:00, 3342.31it/s]ROC-AUC: 76.89409722222223
# LSA coverage: 5.4
# Found saved train ATs, skip serving
# Found saved 128 ATs, skip serving
# The number of removed columns: 0
# [128] Fetching LSA
#
# kde: 100%|██████████| 2/2 [00:00<00:00, 401.00it/s]
# 100%|██████████| 250/250 [00:00<00:00, 3056.95it/s]ROC-AUC: 73.56336805555556
# LSA coverage: 5.2
# Found saved train ATs, skip serving
# Found saved 129 ATs, skip serving
# The number of removed columns: 0
# [129] Fetching LSA
#
# kde: 100%|██████████| 2/2 [00:00<00:00, 334.26it/s]
# 100%|██████████| 250/250 [00:00<00:00, 3255.45it/s]ROC-AUC: 68.06597222222221
# LSA coverage: 5.6000000000000005
# Found saved train ATs, skip serving
# Found saved 130 ATs, skip serving
# The number of removed columns: 0
# [130] Fetching LSA
#
# kde: 100%|██████████| 2/2 [00:00<00:00, 668.52it/s]
# 100%|██████████| 250/250 [00:00<00:00, 3387.40it/s]ROC-AUC: 62.68229166666668
# LSA coverage: 7.000000000000001
# Found saved train ATs, skip serving
# Found saved 131 ATs, skip serving
# The number of removed columns: 0
# [131] Fetching LSA
#
# kde: 100%|██████████| 2/2 [00:00<00:00, 401.10it/s]
# 100%|██████████| 250/250 [00:00<00:00, 3172.99it/s]ROC-AUC: 56.52777777777778
# LSA coverage: 8.1
# Found saved train ATs, skip serving
# Found saved 132 ATs, skip serving
# The number of removed columns: 0
# [132] Fetching LSA
#
# kde: 100%|██████████| 2/2 [00:00<00:00, 401.10it/s]
# 100%|██████████| 250/250 [00:00<00:00, 3433.83it/s]ROC-AUC: 51.897569444444436
# LSA coverage: 8.7
# Found saved train ATs, skip serving
# Found saved 133 ATs, skip serving
# The number of removed columns: 0
# [133] Fetching LSA
#
# kde: 100%|██████████| 2/2 [00:00<00:00, 401.18it/s]
# 100%|██████████| 250/250 [00:00<00:00, 3342.22it/s]ROC-AUC: 48.25000000000001
# LSA coverage: 10.2
# Found saved train ATs, skip serving
# Found saved 134 ATs, skip serving
# The number of removed columns: 0
# [134] Fetching LSA
#
# kde: 100%|██████████| 2/2 [00:00<00:00, 401.00it/s]
# 100%|██████████| 250/250 [00:00<00:00, 3255.49it/s]ROC-AUC: 44.44444444444444
# LSA coverage: 10.5
# Found saved train ATs, skip serving
# Found saved 135 ATs, skip serving
# The number of removed columns: 0
# [135] Fetching LSA
#
# kde: 100%|██████████| 2/2 [00:00<00:00, 501.50it/s]
# 100%|██████████| 250/250 [00:00<00:00, 3212.72it/s]ROC-AUC: 41.15624999999999
# LSA coverage: 10.8
# Found saved train ATs, skip serving
# Found saved 136 ATs, skip serving
# The number of removed columns: 0
# [136] Fetching LSA
#
# kde: 100%|██████████| 2/2 [00:00<00:00, 401.08it/s]
# 100%|██████████| 250/250 [00:00<00:00, 3094.70it/s]ROC-AUC: 38.27083333333333
# LSA coverage: 11.200000000000001
# Found saved train ATs, skip serving
# Found saved 137 ATs, skip serving
# The number of removed columns: 0
# [137] Fetching LSA
#
# kde: 100%|██████████| 2/2 [00:00<00:00, 403.71it/s]
# 100%|██████████| 250/250 [00:00<00:00, 3173.00it/s]ROC-AUC: 37.2361111111111
# LSA coverage: 11.0
# Found saved train ATs, skip serving
# Found saved 138 ATs, skip serving
# The number of removed columns: 0
# [138] Fetching LSA
#
# kde: 100%|██████████| 2/2 [00:00<00:00, 505.28it/s]
# 100%|██████████| 250/250 [00:00<00:00, 3387.20it/s]ROC-AUC: 34.58159722222223
# LSA coverage: 10.6
# Found saved train ATs, skip serving
# Found saved 139 ATs, skip serving
# The number of removed columns: 0
# [139] Fetching LSA
#
# kde: 100%|██████████| 2/2 [00:00<00:00, 399.91it/s]
# 100%|██████████| 250/250 [00:00<00:00, 3255.31it/s]ROC-AUC: 30.432291666666668
# LSA coverage: 9.3
# Found saved train ATs, skip serving
# Found saved 140 ATs, skip serving
# The number of removed columns: 0
# [140] Fetching LSA
#
# kde: 100%|██████████| 2/2 [00:00<00:00, 401.23it/s]
# 100%|██████████| 250/250 [00:00<00:00, 3298.24it/s]ROC-AUC: 29.427083333333332
# LSA coverage: 8.6
# Found saved train ATs, skip serving
# Found saved 141 ATs, skip serving
# The number of removed columns: 0
# [141] Fetching LSA
#
# kde: 100%|██████████| 2/2 [00:00<00:00, 401.10it/s]
# 100%|██████████| 250/250 [00:00<00:00, 3298.21it/s]ROC-AUC: 26.133680555555554
# LSA coverage: 7.5
# Found saved train ATs, skip serving
# Found saved 142 ATs, skip serving
# The number of removed columns: 0
# [142] Fetching LSA
#
# kde: 100%|██████████| 2/2 [00:00<00:00, 403.65it/s]
# 100%|██████████| 250/250 [00:00<00:00, 2815.81it/s]ROC-AUC: 24.980902777777775
# LSA coverage: 7.199999999999999
# Found saved train ATs, skip serving
# Found saved 143 ATs, skip serving
# The number of removed columns: 0
# [143] Fetching LSA
#
# kde: 100%|██████████| 2/2 [00:00<00:00, 501.38it/s]
# 100%|██████████| 250/250 [00:00<00:00, 3530.48it/s]ROC-AUC: 23.178819444444446
# LSA coverage: 6.2
# Found saved train ATs, skip serving
# Found saved 144 ATs, skip serving
# The number of removed columns: 0
# [144] Fetching LSA
#
# kde: 100%|██████████| 2/2 [00:00<00:00, 334.26it/s]
# 100%|██████████| 250/250 [00:00<00:00, 3298.30it/s]ROC-AUC: 21.765625
# LSA coverage: 6.0
# Found saved train ATs, skip serving
# Found saved 145 ATs, skip serving
# The number of removed columns: 0
# [145] Fetching LSA
#
# kde: 100%|██████████| 2/2 [00:00<00:00, 401.10it/s]
# 100%|██████████| 250/250 [00:00<00:00, 3433.80it/s]ROC-AUC: 20.289930555555554
# LSA coverage: 4.8
# Found saved train ATs, skip serving
# Found saved 146 ATs, skip serving
# The number of removed columns: 0
# [146] Fetching LSA
#
# kde: 100%|██████████| 2/2 [00:00<00:00, 401.16it/s]
# 100%|██████████| 250/250 [00:00<00:00, 3213.73it/s]ROC-AUC: 79.27430555555554
# LSA coverage: 5.1
# Found saved train ATs, skip serving
# Found saved 147 ATs, skip serving
# The number of removed columns: 0
# [147] Fetching LSA
#
# kde: 100%|██████████| 2/2 [00:00<00:00, 401.02it/s]
# 100%|██████████| 250/250 [00:00<00:00, 3297.16it/s]ROC-AUC: 78.47048611111111
# LSA coverage: 4.9
# Found saved train ATs, skip serving
# Found saved 148 ATs, skip serving
# The number of removed columns: 0
# [148] Fetching LSA
#
# kde: 100%|██████████| 2/2 [00:00<00:00, 668.41it/s]
# 100%|██████████| 250/250 [00:00<00:00, 3387.40it/s]ROC-AUC: 21.392361111111114
# LSA coverage: 5.5
# Found saved train ATs, skip serving
# Found saved 149 ATs, skip serving
# The number of removed columns: 0
# [149] Fetching LSA
#
# kde: 100%|██████████| 2/2 [00:00<00:00, 501.41it/s]
# 100%|██████████| 250/250 [00:00<00:00, 3173.03it/s]ROC-AUC: 76.61631944444444
# LSA coverage: 5.5
# Found saved train ATs, skip serving
# Found saved 150 ATs, skip serving
# The number of removed columns: 0
# [150] Fetching LSA
#
# kde: 100%|██████████| 2/2 [00:00<00:00, 401.02it/s]
# 100%|██████████| 250/250 [00:00<00:00, 3481.50it/s]ROC-AUC: 76.21354166666667
# LSA coverage: 5.8999999999999995
# Found saved train ATs, skip serving
# Found saved 151 ATs, skip serving
# The number of removed columns: 0
# [151] Fetching LSA
#
# kde: 100%|██████████| 2/2 [00:00<00:00, 401.04it/s]
# 100%|██████████| 250/250 [00:00<00:00, 3580.91it/s]ROC-AUC: 75.77604166666667
# LSA coverage: 5.7
# Found saved train ATs, skip serving
# Found saved 152 ATs, skip serving
# The number of removed columns: 0
# [152] Fetching LSA
#
# kde: 100%|██████████| 2/2 [00:00<00:00, 501.41it/s]
# 100%|██████████| 250/250 [00:00<00:00, 2983.32it/s]ROC-AUC: 76.4548611111111
# LSA coverage: 5.7
# Found saved train ATs, skip serving
# Found saved 153 ATs, skip serving
# The number of removed columns: 0
# [153] Fetching LSA
#
# kde: 100%|██████████| 2/2 [00:00<00:00, 501.38it/s]
# 100%|██████████| 250/250 [00:00<00:00, 3213.70it/s]ROC-AUC: 76.43923611111111
# LSA coverage: 5.8999999999999995
# Found saved train ATs, skip serving
# Found saved 154 ATs, skip serving
# The number of removed columns: 0
# [154] Fetching LSA
#
# kde: 100%|██████████| 2/2 [00:00<00:00, 501.26it/s]
# 100%|██████████| 250/250 [00:00<00:00, 3481.49it/s]ROC-AUC: 76.75
# LSA coverage: 5.6000000000000005
# Found saved train ATs, skip serving
# Found saved 155 ATs, skip serving
# The number of removed columns: 0
# [155] Fetching LSA
#
# kde: 100%|██████████| 2/2 [00:00<00:00, 501.44it/s]
# 100%|██████████| 250/250 [00:00<00:00, 3342.26it/s]ROC-AUC: 22.473958333333332
# LSA coverage: 5.7
# Found saved train ATs, skip serving
# Found saved 156 ATs, skip serving
# The number of removed columns: 0
# [156] Fetching LSA
#
# kde: 100%|██████████| 2/2 [00:00<00:00, 401.10it/s]
# 100%|██████████| 250/250 [00:00<00:00, 3433.77it/s]ROC-AUC: 22.048611111111107
# LSA coverage: 6.0
# Found saved train ATs, skip serving
# Found saved 157 ATs, skip serving
# The number of removed columns: 0
# [157] Fetching LSA
#
# kde: 100%|██████████| 2/2 [00:00<00:00, 501.38it/s]
# 100%|██████████| 250/250 [00:00<00:00, 3093.74it/s]ROC-AUC: 20.946180555555554
# LSA coverage: 5.5
# Found saved train ATs, skip serving
# Found saved 158 ATs, skip serving
# The number of removed columns: 0
# [158] Fetching LSA
#
# kde: 100%|██████████| 2/2 [00:00<00:00, 501.32it/s]
# 100%|██████████| 250/250 [00:00<00:00, 3255.42it/s]ROC-AUC: 20.04861111111111
# LSA coverage: 5.3
# Found saved train ATs, skip serving
# Found saved 159 ATs, skip serving
# The number of removed columns: 0
# [159] Fetching LSA
#
# kde: 100%|██████████| 2/2 [00:00<00:00, 334.25it/s]
# 100%|██████████| 250/250 [00:00<00:00, 3632.89it/s]ROC-AUC: 19.342013888888886
# LSA coverage: 5.2
# Found saved train ATs, skip serving
# Found saved 160 ATs, skip serving
# The number of removed columns: 0
# [160] Fetching LSA
#
# kde: 100%|██████████| 2/2 [00:00<00:00, 401.20it/s]
# 100%|██████████| 250/250 [00:00<00:00, 3094.68it/s]ROC-AUC: 18.203124999999996
# LSA coverage: 4.9
# Found saved train ATs, skip serving
# Found saved 161 ATs, skip serving
# The number of removed columns: 0
# [161] Fetching LSA
#
# kde: 100%|██████████| 2/2 [00:00<00:00, 401.08it/s]
# 100%|██████████| 250/250 [00:00<00:00, 3340.95it/s]ROC-AUC: 17.40625
# LSA coverage: 4.7
# Found saved train ATs, skip serving
# Found saved 162 ATs, skip serving
# The number of removed columns: 0
# [162] Fetching LSA
#
# kde: 100%|██████████| 2/2 [00:00<00:00, 501.41it/s]
# 100%|██████████| 250/250 [00:00<00:00, 3386.16it/s]ROC-AUC: 17.880208333333336
# LSA coverage: 4.5
# Found saved train ATs, skip serving
# Found saved 163 ATs, skip serving
# The number of removed columns: 0
# [163] Fetching LSA
#
# kde: 100%|██████████| 2/2 [00:00<00:00, 400.26it/s]
# 100%|██████████| 250/250 [00:00<00:00, 2984.15it/s]ROC-AUC: 81.7048611111111
# LSA coverage: 4.1000000000000005
# Found saved train ATs, skip serving
# Found saved 164 ATs, skip serving
# The number of removed columns: 0
# [164] Fetching LSA
#
# ROC-AUC: 81.65451388888889
# LSA coverage: 4.3

# %%
lsa_result = pd.DataFrame(np.array([test_cov,test_auc]).T,columns=['cov','auc'])
lsa_result
# Out:
#       cov       auc
# 0    14.1  0.610417
# 1    13.3  0.574583
# 2    12.9  0.557344
# 3    12.1  0.527292
# 4    11.9  0.526267
# ..    ...       ...
# 159   4.9  0.182031
# 160   4.7  0.174063
# 161   4.5  0.178802
# 162   4.1  0.817049
# 163   4.3  0.816545
#
# [164 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
lsa_result = pd.DataFrame(np.array([test_cov,test_auc]).T,columns=['cov','auc'])
lsa_down = lsa_result.sort_values('cov',ascending=False)
lsa_up = lsa_result.sort_values('cov')
x = range(0,164,1)
plt.plot(x,lsa_up['auc'].rolling(164, min_periods=1).mean(),label='Ascending Lsa')
plt.plot(x,lsa_down['auc'].rolling(164, min_periods=1).mean(),label='Descending Lsa')
plt.plot(x,lsa_result.sample(frac=1)['auc'].rolling(164, min_periods=1).mean(),label='Random Lsa')
plt.legend()

# %%
num=0
dsa_auc = []
dsa_cov = []
test_dsa = fetch_dsa(model, x_train, x_test, "test", layer_names, args)
for x_test in all_x_test:
    num=num+1
    target_dsa = fetch_dsa(model, x_train, x_test, str(num), layer_names, args)
    # target_dsa = fetch_dsa(model, x_train, x_target, args.target, layer_names, args)
    target_cov = get_sc(
        np.amin(target_dsa), default_upper_bound, default_n_bucket, target_dsa
    )

    auc = compute_roc_auc(test_dsa, target_dsa, 10)
    dsa_auc.append(auc)
    dsa_cov.append(target_cov)
    print(infog("ROC-AUC: " + str(auc * 100)))

    print(infog("dsa coverage: " + str(target_cov)))
    if num >= 164:
        break
# Out:
# .6935763888889
# dsa coverage: 0.3
# Found saved train ATs, skip serving
# Found saved 78 ATs, skip serving
# [78] Fetching DSA
#
# 100%|██████████| 250/250 [00:00<00:00, 4476.37it/s]ROC-AUC: 38.49826388888889
# dsa coverage: 0.3
# Found saved train ATs, skip serving
# Found saved 79 ATs, skip serving
# [79] Fetching DSA
#
# 100%|██████████| 250/250 [00:00<00:00, 4820.60it/s]ROC-AUC: 35.333333333333336
# dsa coverage: 0.3
# Found saved train ATs, skip serving
# Found saved 80 ATs, skip serving
# [80] Fetching DSA
#
# 100%|██████████| 250/250 [00:00<00:00, 5113.88it/s]ROC-AUC: 33.75
# dsa coverage: 0.2
# Found saved train ATs, skip serving
# Found saved 81 ATs, skip serving
# [81] Fetching DSA
#
# 100%|██████████| 250/250 [00:00<00:00, 4321.94it/s]ROC-AUC: 32.885416666666664
# dsa coverage: 0.2
# Found saved train ATs, skip serving
# Found saved 82 ATs, skip serving
# [82] Fetching DSA
#
# 100%|██████████| 250/250 [00:00<00:00, 4557.74it/s]ROC-AUC: 33.26041666666667
# dsa coverage: 0.2
# Found saved train ATs, skip serving
# Found saved 83 ATs, skip serving
# [83] Fetching DSA
#
# 100%|██████████| 250/250 [00:00<00:00, 4557.90it/s]ROC-AUC: 64.3125
# dsa coverage: 0.3
# Found saved train ATs, skip serving
# Found saved 84 ATs, skip serving
# [84] Fetching DSA
#
# 100%|██████████| 250/250 [00:00<00:00, 4915.09it/s]ROC-AUC: 60.81770833333333
# dsa coverage: 0.3
# Found saved train ATs, skip serving
# Found saved 85 ATs, skip serving
# [85] Fetching DSA
#
# 100%|██████████| 250/250 [00:00<00:00, 5115.93it/s]ROC-AUC: 40.98784722222222
# dsa coverage: 0.3
# Found saved train ATs, skip serving
# Found saved 86 ATs, skip serving
# [86] Fetching DSA
#
# 100%|██████████| 250/250 [00:00<00:00, 4912.24it/s]ROC-AUC: 42.713541666666664
# dsa coverage: 0.3
# Found saved train ATs, skip serving
# Found saved 87 ATs, skip serving
# [87] Fetching DSA
#
# 100%|██████████| 250/250 [00:00<00:00, 5010.25it/s]ROC-AUC: 44.24652777777778
# dsa coverage: 0.3
# Found saved train ATs, skip serving
# Found saved 88 ATs, skip serving
# [88] Fetching DSA
#
# 100%|██████████| 250/250 [00:00<00:00, 5112.69it/s]ROC-AUC: 46.489583333333336
# dsa coverage: 0.3
# Found saved train ATs, skip serving
# Found saved 89 ATs, skip serving
# [89] Fetching DSA
#
# 100%|██████████| 250/250 [00:00<00:00, 5221.78it/s]ROC-AUC: 46.697916666666664
# dsa coverage: 0.3
# Found saved train ATs, skip serving
# Found saved 90 ATs, skip serving
# [90] Fetching DSA
#
# 100%|██████████| 250/250 [00:00<00:00, 4557.78it/s]ROC-AUC: 46.970486111111114
# dsa coverage: 0.3
# Found saved train ATs, skip serving
# Found saved 91 ATs, skip serving
# [91] Fetching DSA
#
# 100%|██████████| 250/250 [00:00<00:00, 4823.08it/s]ROC-AUC: 47.66145833333334
# dsa coverage: 0.3
# Found saved train ATs, skip serving
# Found saved 92 ATs, skip serving
# [92] Fetching DSA
#
# 100%|██████████| 250/250 [00:00<00:00, 4729.60it/s]ROC-AUC: 48.31597222222222
# dsa coverage: 0.3
# Found saved train ATs, skip serving
# Found saved 93 ATs, skip serving
# [93] Fetching DSA
#
# 100%|██████████| 250/250 [00:00<00:00, 4726.59it/s]ROC-AUC: 48.38020833333333
# dsa coverage: 0.4
# Found saved train ATs, skip serving
# Found saved 94 ATs, skip serving
# [94] Fetching DSA
#
# 100%|██████████| 250/250 [00:00<00:00, 4397.85it/s]ROC-AUC: 54.21180555555556
# dsa coverage: 0.4
# Found saved train ATs, skip serving
# Found saved 95 ATs, skip serving
# [95] Fetching DSA
#
# 100%|██████████| 250/250 [00:00<00:00, 4820.68it/s]ROC-AUC: 42.39062500000001
# dsa coverage: 0.4
# Found saved train ATs, skip serving
# Found saved 96 ATs, skip serving
# [96] Fetching DSA
#
# 100%|██████████| 250/250 [00:00<00:00, 4638.96it/s]ROC-AUC: 38.67881944444444
# dsa coverage: 0.4
# Found saved train ATs, skip serving
# Found saved 97 ATs, skip serving
# [97] Fetching DSA
#
# 100%|██████████| 250/250 [00:00<00:00, 4554.87it/s]ROC-AUC: 63.66666666666667
# dsa coverage: 0.4
# Found saved train ATs, skip serving
# Found saved 98 ATs, skip serving
# [98] Fetching DSA
#
# 100%|██████████| 250/250 [00:00<00:00, 5013.32it/s]ROC-AUC: 65.40104166666667
# dsa coverage: 0.4
# Found saved train ATs, skip serving
# Found saved 99 ATs, skip serving
# [99] Fetching DSA
#
# 100%|██████████| 250/250 [00:00<00:00, 4915.16it/s]ROC-AUC: 68.64062499999999
# dsa coverage: 0.4
# Found saved train ATs, skip serving
# Found saved 100 ATs, skip serving
# [100] Fetching DSA
#
# 100%|██████████| 250/250 [00:00<00:00, 5013.51it/s]ROC-AUC: 28.741319444444446
# dsa coverage: 0.4
# Found saved train ATs, skip serving
# Found saved 101 ATs, skip serving
# [101] Fetching DSA
#
# 100%|██████████| 250/250 [00:00<00:00, 4476.33it/s]ROC-AUC: 27.29861111111111
# dsa coverage: 0.4
# Found saved train ATs, skip serving
# Found saved 102 ATs, skip serving
# [102] Fetching DSA
#
# 100%|██████████| 250/250 [00:00<00:00, 3916.84it/s]ROC-AUC: 24.255208333333332
# dsa coverage: 0.4
# Found saved train ATs, skip serving
# Found saved 103 ATs, skip serving
# [103] Fetching DSA
#
# 100%|██████████| 250/250 [00:00<00:00, 4820.62it/s]ROC-AUC: 78.33680555555556
# dsa coverage: 0.4
# Found saved train ATs, skip serving
# Found saved 104 ATs, skip serving
# [104] Fetching DSA
#
# 100%|██████████| 250/250 [00:00<00:00, 4555.22it/s]ROC-AUC: 79.58680555555556
# dsa coverage: 0.4
# Found saved train ATs, skip serving
# Found saved 105 ATs, skip serving
# [105] Fetching DSA
#
# 100%|██████████| 250/250 [00:00<00:00, 4473.75it/s]ROC-AUC: 81.47048611111111
# dsa coverage: 0.4
# Found saved train ATs, skip serving
# Found saved 106 ATs, skip serving
# [106] Fetching DSA
#
# 100%|██████████| 250/250 [00:00<00:00, 5112.61it/s]ROC-AUC: 84.2378472222222
# dsa coverage: 0.4
# Found saved train ATs, skip serving
# Found saved 107 ATs, skip serving
# [107] Fetching DSA
#
# 100%|██████████| 250/250 [00:00<00:00, 4917.65it/s]ROC-AUC: 84.92708333333333
# dsa coverage: 0.4
# Found saved train ATs, skip serving
# Found saved 108 ATs, skip serving
# [108] Fetching DSA
#
# 100%|██████████| 250/250 [00:00<00:00, 4557.72it/s]ROC-AUC: 84.34895833333333
# dsa coverage: 0.5
# Found saved train ATs, skip serving
# Found saved 109 ATs, skip serving
# [109] Fetching DSA
#
# 100%|██████████| 250/250 [00:00<00:00, 5221.11it/s]ROC-AUC: 83.61284722222223
# dsa coverage: 0.5
# Found saved train ATs, skip serving
# Found saved 110 ATs, skip serving
# [110] Fetching DSA
#
# 100%|██████████| 250/250 [00:00<00:00, 4729.64it/s]ROC-AUC: 83.703125
# dsa coverage: 0.5
# Found saved train ATs, skip serving
# Found saved 111 ATs, skip serving
# [111] Fetching DSA
#
# 100%|██████████| 250/250 [00:00<00:00, 5113.01it/s]ROC-AUC: 84.98958333333334
# dsa coverage: 0.5
# Found saved train ATs, skip serving
# Found saved 112 ATs, skip serving
# [112] Fetching DSA
#
# 100%|██████████| 250/250 [00:00<00:00, 4557.64it/s]ROC-AUC: 85.77170138888889
# dsa coverage: 0.5
# Found saved train ATs, skip serving
# Found saved 113 ATs, skip serving
# [113] Fetching DSA
#
# 100%|██████████| 250/250 [00:00<00:00, 4554.89it/s]ROC-AUC: 85.9392361111111
# dsa coverage: 0.5
# Found saved train ATs, skip serving
# Found saved 114 ATs, skip serving
# [114] Fetching DSA
#
# 100%|██████████| 250/250 [00:00<00:00, 4557.68it/s]ROC-AUC: 87.1388888888889
# dsa coverage: 0.5
# Found saved train ATs, skip serving
# Found saved 115 ATs, skip serving
# [115] Fetching DSA
#
# 100%|██████████| 250/250 [00:00<00:00, 4915.12it/s]ROC-AUC: 89.0
# dsa coverage: 0.5
# Found saved train ATs, skip serving
# Found saved 116 ATs, skip serving
# [116] Fetching DSA
#
# 100%|██████████| 250/250 [00:00<00:00, 4912.44it/s]ROC-AUC: 90.01041666666667
# dsa coverage: 0.5
# Found saved train ATs, skip serving
# Found saved 117 ATs, skip serving
# [117] Fetching DSA
#
# 100%|██████████| 250/250 [00:00<00:00, 5218.87it/s]ROC-AUC: 88.80729166666667
# dsa coverage: 0.5
# Found saved train ATs, skip serving
# Found saved 118 ATs, skip serving
# [118] Fetching DSA
#
# 100%|██████████| 250/250 [00:00<00:00, 4729.90it/s]ROC-AUC: 88.53472222222221
# dsa coverage: 0.5
# Found saved train ATs, skip serving
# Found saved 119 ATs, skip serving
# [119] Fetching DSA
#
# 100%|██████████| 250/250 [00:00<00:00, 4729.66it/s]ROC-AUC: 88.20833333333334
# dsa coverage: 0.5
# Found saved train ATs, skip serving
# Found saved 120 ATs, skip serving
# [120] Fetching DSA
#
# 100%|██████████| 250/250 [00:00<00:00, 4557.82it/s]ROC-AUC: 87.81597222222221
# dsa coverage: 0.5
# Found saved train ATs, skip serving
# Found saved 121 ATs, skip serving
# [121] Fetching DSA
#
# 100%|██████████| 250/250 [00:00<00:00, 5010.16it/s]ROC-AUC: 88.15972222222223
# dsa coverage: 0.5
# Found saved train ATs, skip serving
# Found saved 122 ATs, skip serving
# [122] Fetching DSA
#
# 100%|██████████| 250/250 [00:00<00:00, 4557.64it/s]ROC-AUC: 85.41840277777777
# dsa coverage: 0.5
# Found saved train ATs, skip serving
# Found saved 123 ATs, skip serving
# [123] Fetching DSA
#
# 100%|██████████| 250/250 [00:00<00:00, 5570.48it/s]ROC-AUC: 83.26388888888889
# dsa coverage: 0.5
# Found saved train ATs, skip serving
# Found saved 124 ATs, skip serving
# [124] Fetching DSA
#
# 100%|██████████| 250/250 [00:00<00:00, 4823.08it/s]ROC-AUC: 80.69097222222221
# dsa coverage: 0.5
# Found saved train ATs, skip serving
# Found saved 125 ATs, skip serving
# [125] Fetching DSA
#
# 100%|██████████| 250/250 [00:00<00:00, 4395.35it/s]ROC-AUC: 78.87326388888889
# dsa coverage: 0.5
# Found saved train ATs, skip serving
# Found saved 126 ATs, skip serving
# [126] Fetching DSA
#
# 100%|██████████| 250/250 [00:00<00:00, 4397.76it/s]ROC-AUC: 77.31076388888889
# dsa coverage: 0.5
# Found saved train ATs, skip serving
# Found saved 127 ATs, skip serving
# [127] Fetching DSA
#
# 100%|██████████| 250/250 [00:00<00:00, 4248.57it/s]ROC-AUC: 73.03993055555556
# dsa coverage: 0.5
# Found saved train ATs, skip serving
# Found saved 128 ATs, skip serving
# [128] Fetching DSA
#
# 100%|██████████| 250/250 [00:00<00:00, 4555.60it/s]ROC-AUC: 71.3515625
# dsa coverage: 0.5
# Found saved train ATs, skip serving
# Found saved 129 ATs, skip serving
# [129] Fetching DSA
#
# 100%|██████████| 250/250 [00:00<00:00, 4248.72it/s]ROC-AUC: 68.29861111111111
# dsa coverage: 0.5
# Found saved train ATs, skip serving
# Found saved 130 ATs, skip serving
# [130] Fetching DSA
#
# 100%|██████████| 250/250 [00:00<00:00, 5013.37it/s]ROC-AUC: 63.97222222222222
# dsa coverage: 0.5
# Found saved train ATs, skip serving
# Found saved 131 ATs, skip serving
# [131] Fetching DSA
#
# 100%|██████████| 250/250 [00:00<00:00, 4557.66it/s]ROC-AUC: 59.80034722222223
# dsa coverage: 0.5
# Found saved train ATs, skip serving
# Found saved 132 ATs, skip serving
# [132] Fetching DSA
#
# 100%|██████████| 250/250 [00:00<00:00, 4397.85it/s]ROC-AUC: 54.96006944444445
# dsa coverage: 0.4
# Found saved train ATs, skip serving
# Found saved 133 ATs, skip serving
# [133] Fetching DSA
#
# 100%|██████████| 250/250 [00:00<00:00, 4395.29it/s]ROC-AUC: 51.83333333333333
# dsa coverage: 0.4
# Found saved train ATs, skip serving
# Found saved 134 ATs, skip serving
# [134] Fetching DSA
#
# 100%|██████████| 250/250 [00:00<00:00, 4918.39it/s]ROC-AUC: 48.30555555555554
# dsa coverage: 0.3
# Found saved train ATs, skip serving
# Found saved 135 ATs, skip serving
# [135] Fetching DSA
#
# 100%|██████████| 250/250 [00:00<00:00, 5115.85it/s]ROC-AUC: 44.91319444444444
# dsa coverage: 0.3
# Found saved train ATs, skip serving
# Found saved 136 ATs, skip serving
# [136] Fetching DSA
#
# 100%|██████████| 250/250 [00:00<00:00, 4817.47it/s]ROC-AUC: 42.88020833333333
# dsa coverage: 0.3
# Found saved train ATs, skip serving
# Found saved 137 ATs, skip serving
# [137] Fetching DSA
#
# 100%|██████████| 250/250 [00:00<00:00, 4726.72it/s]ROC-AUC: 40.67708333333333
# dsa coverage: 0.2
# Found saved train ATs, skip serving
# Found saved 138 ATs, skip serving
# [138] Fetching DSA
#
# 100%|██████████| 250/250 [00:00<00:00, 3481.84it/s]ROC-AUC: 38.42534722222222
# dsa coverage: 0.3
# Found saved train ATs, skip serving
# Found saved 139 ATs, skip serving
# [139] Fetching DSA
#
# 100%|██████████| 250/250 [00:00<00:00, 4820.64it/s]ROC-AUC: 35.185763888888886
# dsa coverage: 0.2
# Found saved train ATs, skip serving
# Found saved 140 ATs, skip serving
# [140] Fetching DSA
#
# 100%|██████████| 250/250 [00:00<00:00, 4557.76it/s]ROC-AUC: 34.86631944444445
# dsa coverage: 0.2
# Found saved train ATs, skip serving
# Found saved 141 ATs, skip serving
# [141] Fetching DSA
#
# 100%|██████████| 250/250 [00:00<00:00, 4729.64it/s]ROC-AUC: 65.17187499999999
# dsa coverage: 0.2
# Found saved train ATs, skip serving
# Found saved 142 ATs, skip serving
# [142] Fetching DSA
#
# 100%|██████████| 250/250 [00:00<00:00, 4476.43it/s]ROC-AUC: 33.50347222222222
# dsa coverage: 0.2
# Found saved train ATs, skip serving
# Found saved 143 ATs, skip serving
# [143] Fetching DSA
#
# 100%|██████████| 250/250 [00:00<00:00, 4474.00it/s]ROC-AUC: 33.58680555555556
# dsa coverage: 0.2
# Found saved train ATs, skip serving
# Found saved 144 ATs, skip serving
# [144] Fetching DSA
#
# 100%|██████████| 250/250 [00:00<00:00, 5010.13it/s]ROC-AUC: 32.751736111111114
# dsa coverage: 0.2
# Found saved train ATs, skip serving
# Found saved 145 ATs, skip serving
# [145] Fetching DSA
#
# 100%|██████████| 250/250 [00:00<00:00, 4557.74it/s]ROC-AUC: 30.944444444444443
# dsa coverage: 0.2
# Found saved train ATs, skip serving
# Found saved 146 ATs, skip serving
# [146] Fetching DSA
#
# 100%|██████████| 250/250 [00:00<00:00, 4915.21it/s]ROC-AUC: 30.940972222222218
# dsa coverage: 0.2
# Found saved train ATs, skip serving
# Found saved 147 ATs, skip serving
# [147] Fetching DSA
#
# 100%|██████████| 250/250 [00:00<00:00, 5115.88it/s]ROC-AUC: 30.786458333333332
# dsa coverage: 0.2
# Found saved train ATs, skip serving
# Found saved 148 ATs, skip serving
# [148] Fetching DSA
#
# 100%|██████████| 250/250 [00:00<00:00, 4639.66it/s]ROC-AUC: 68.51041666666666
# dsa coverage: 0.2
# Found saved train ATs, skip serving
# Found saved 149 ATs, skip serving
# [149] Fetching DSA
#
# 100%|██████████| 250/250 [00:00<00:00, 4557.82it/s]ROC-AUC: 67.13541666666667
# dsa coverage: 0.2
# Found saved train ATs, skip serving
# Found saved 150 ATs, skip serving
# [150] Fetching DSA
#
# 100%|██████████| 250/250 [00:00<00:00, 4642.20it/s]ROC-AUC: 67.35243055555556
# dsa coverage: 0.2
# Found saved train ATs, skip serving
# Found saved 151 ATs, skip serving
# [151] Fetching DSA
#
# 100%|██████████| 250/250 [00:00<00:00, 5010.73it/s]ROC-AUC: 66.5373263888889
# dsa coverage: 0.2
# Found saved train ATs, skip serving
# Found saved 152 ATs, skip serving
# [152] Fetching DSA
#
# 100%|██████████| 250/250 [00:00<00:00, 4729.58it/s]ROC-AUC: 31.96875
# dsa coverage: 0.2
# Found saved train ATs, skip serving
# Found saved 153 ATs, skip serving
# [153] Fetching DSA
#
# 100%|██████████| 250/250 [00:00<00:00, 4177.81it/s]ROC-AUC: 30.828124999999996
# dsa coverage: 0.2
# Found saved train ATs, skip serving
# Found saved 154 ATs, skip serving
# [154] Fetching DSA
#
# 100%|██████████| 250/250 [00:00<00:00, 4820.62it/s]ROC-AUC: 30.96006944444445
# dsa coverage: 0.2
# Found saved train ATs, skip serving
# Found saved 155 ATs, skip serving
# [155] Fetching DSA
#
# 100%|██████████| 250/250 [00:00<00:00, 4729.71it/s]ROC-AUC: 31.76909722222222
# dsa coverage: 0.2
# Found saved train ATs, skip serving
# Found saved 156 ATs, skip serving
# [156] Fetching DSA
#
# 100%|██████████| 250/250 [00:00<00:00, 5010.40it/s]ROC-AUC: 31.37152777777778
# dsa coverage: 0.2
# Found saved train ATs, skip serving
# Found saved 157 ATs, skip serving
# [157] Fetching DSA
#
# 100%|██████████| 250/250 [00:00<00:00, 4729.64it/s]ROC-AUC: 31.991319444444443
# dsa coverage: 0.2
# Found saved train ATs, skip serving
# Found saved 158 ATs, skip serving
# [158] Fetching DSA
#
# 100%|██████████| 250/250 [00:00<00:00, 4642.10it/s]ROC-AUC: 33.36284722222223
# dsa coverage: 0.2
# Found saved train ATs, skip serving
# Found saved 159 ATs, skip serving
# [159] Fetching DSA
#
# 100%|██████████| 250/250 [00:00<00:00, 4321.92it/s]ROC-AUC: 65.88368055555556
# dsa coverage: 0.2
# Found saved train ATs, skip serving
# Found saved 160 ATs, skip serving
# [160] Fetching DSA
#
# 100%|██████████| 250/250 [00:00<00:00, 4820.80it/s]ROC-AUC: 33.79166666666667
# dsa coverage: 0.2
# Found saved train ATs, skip serving
# Found saved 161 ATs, skip serving
# [161] Fetching DSA
#
# 100%|██████████| 250/250 [00:00<00:00, 4820.55it/s]ROC-AUC: 33.30034722222223
# dsa coverage: 0.2
# Found saved train ATs, skip serving
# Found saved 162 ATs, skip serving
# [162] Fetching DSA
#
# 100%|██████████| 250/250 [00:00<00:00, 4729.56it/s]ROC-AUC: 33.11284722222222
# dsa coverage: 0.2
# Found saved train ATs, skip serving
# Found saved 163 ATs, skip serving
# [163] Fetching DSA
#
# 100%|██████████| 250/250 [00:00<00:00, 3798.03it/s]ROC-AUC: 33.38194444444444
# dsa coverage: 0.2
# Found saved train ATs, skip serving
# Found saved 164 ATs, skip serving
# [164] Fetching DSA
#
# ROC-AUC: 32.75347222222222
# dsa coverage: 0.2

# %%
dsa_result
# Out:
#      cov       auc
# 0    0.3  0.616649
# 1    0.3  0.596163
# 2    0.3  0.569931
# 3    0.3  0.551528
# 4    0.3  0.543003
# ..   ...       ...
# 159  0.2  0.337917
# 160  0.2  0.333003
# 161  0.2  0.331128
# 162  0.2  0.333819
# 163  0.2  0.327535
#
# [164 rows x 2 columns]

# %%
dsa_result = pd.DataFrame(np.array([dsa_cov,dsa_auc]).T,columns=['cov','auc'])
dsa_down = dsa_result.sort_values('cov',ascending=False)
dsa_up = dsa_result.sort_values('cov')
x = range(0,164,1)
plt.plot(x,dsa_up['auc'].rolling(164, min_periods=1).mean(),label='Ascending DSA')
plt.plot(x,dsa_down['auc'].rolling(164, min_periods=1).mean(),label='Descending DSA')
plt.plot(x,dsa_result.sample(frac=1)['auc'].rolling(164, min_periods=1).mean(),label='Random DSA')
plt.legend()
